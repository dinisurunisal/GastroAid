# %%
# !nvidia-smi
# Out:
# Mon May 16 12:24:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Main Libraries

# %%
pip install -q -U tensorflow-addons
# Out:
#      |████████████████████████████████| 1.1 MB 5.4 MB/s

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import datetime
import math
import itertools 
import pickle
import time
import os
import sys
import shutil
import keras
import glob
import cv2
import random
import textwrap
import scipy.ndimage as ndimage
import seaborn as sns

from sklearn.model_selection import train_test_split
from math import ceil, floor
from pathlib import Path
from tqdm import tqdm
from sklearn import metrics
from tqdm.notebook import tqdm
from IPython.display import clear_output
from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# # Setup Colab

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Unzip Datasets

# %%
# !ls "/content/drive/My Drive/ColabNotebooks/Datasets"
# !unzip "/content/drive/My Drive/ColabNotebooks/Datasets/hyperkvasir-labelled-data.zip"
# !unzip "/content/drive/MyDrive/ColabNotebooks/Datasets/hyper-kvasir-unlabeled-images.zip"

# %% [markdown]
# # Initialize

# %%
labeled_data_root = pathlib.Path('/content/hyperkvasir-labelled-data')
unlab_data_root = pathlib.Path('/content/unlabeled-images')

# Primary directory
record_dir = "./records/{}".format("labelled_model")
pathlib.Path(record_dir).mkdir(parents=True, exist_ok=True) # record_directory

cache_dir = "./cache"
pathlib.Path(cache_dir).mkdir(parents=True, exist_ok=True) # cache directory

# %% [markdown]
# # Split Dataset

# %%
# Split the dataset into train, test and validation splits
def split_dataset():

    # The seed() method is used to initialize the random number generator.
    random.seed(1500)
    
    # listdir() returns a list containing the names of the entries in the directory
    class_names = os.listdir(labeled_data_root)
    image_folders = [os.path.join(labeled_data_root, class_name) for class_name in class_names]
    
    num_samples = len(list(Path(labeled_data_root).glob('*/*')))

    # Create folders for each class under the train, test and val folders
    train_folders = [os.path.join('labeled_data', 'train', name) for name in class_names]
    test_folders = [os.path.join('labeled_data', 'test', name) for name in class_names]
    val_folders = [os.path.join('labeled_data', 'val', name) for name in class_names]

    for folder in train_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)

    for folder in test_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)
                              
    for folder in val_folders:
      Path(folder).mkdir(parents=True, exist_ok=True)

    # tqdm is the library which was used to create the Progress Bar
    tqdm_img = tqdm(total=num_samples, desc='Splitting Progress', position=0)

    # split all the classes equally to test, train and val
    for index, directory in enumerate(image_folders):

        random.seed(1500)
        imagenames = os.listdir(directory)
        imagenames.sort() # make sure that the image filenames have a fixed order before shuffling
        random.shuffle(imagenames) # shuffles the ordering of image filenames (deterministic given the chosen seed)
        num_samples = len(imagenames)

        # Here the dataset splits according to the given float values
        imagenames = np.array(imagenames)
        imagenames_split = np.split(imagenames, [floor(num_samples*float(0.7)), floor(num_samples*float(0.85))]) #Train: 70%| Test: 15% | Val: 15%
        
        dataset = {'train': imagenames_split[0],
                   'test': imagenames_split[1],
                   'val': imagenames_split[2]}

        for split in dataset:
            output = os.path.join('labeled_data', split, directory.split("/")[-1])
            for filename in dataset[split]:
                filename = os.path.join(directory, filename)
                image_resize(filename, output) # Resize the image to 128, 128 dimensions
                tqdm_img.update(1) #Updates the Progress Bar

# %%
# Method used to resize the image to 128 size
def image_resize(filename, output_dir):
    image = cv2.imread(filename, cv2.IMREAD_UNCHANGED)
    image = cv2.resize(image, (128, 128), interpolation=cv2.INTER_LINEAR)
    path = os.path.join(output_dir, filename.split('/')[-1])
    cv2.imwrite(path, image) # Save the image in the output directory

# %%
split_dataset()
# Out:
# Splitting Progress:   0%|          | 0/10662 [00:00<?, ?it/s]

# %%
BATCH_SIZE = 8 # Hyperparameter
CLASS_NAMES = None
NUMBER_CLASSES = 0
DATASET_SIZE_TRAIN = None
DATASET_SIZE_TEST = None
DATASET_SIZE_VAL = None
DATASET_SIZE_UNLAB = None
STEPS_TRAIN = None
STEPS_TEST = None
STEPS_VAL = None
RAW_TRAIN_DATASET = None
AUTOTUNE = tf.data.experimental.AUTOTUNE

# function to load input image, preprocess it and get label
def load_label_images(image_path):
    # read the image from database, decode it, convert the data type to
	  # floating point, and then resize it
    image_raw = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image_raw, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [128, 128])

    # parse the class label from the file path
    str_targets = tf.strings.split(image_path, os.path.sep)[-2]
    label_integer = tf.reduce_min(tf.where(tf.equal(str_targets, CLASS_NAMES)))
    label = tf.dtypes.cast(label_integer, tf.int32)

    return image, label

# Method used to organize the datasets, making it suitable to train
def build_datasets():

    global CLASS_NAMES
    global NUMBER_CLASSES
    global DATASET_SIZE_TRAIN
    global DATASET_SIZE_TEST
    global DATASET_SIZE_VAL
    global STEPS_TRAIN
    global STEPS_TEST
    global STEPS_VAL
    global RAW_TRAIN_DATASET

    labeled_data_root = pathlib.Path('/content/labeled_data')
    np.random.seed(seed=1500)

    class_names = np.array([item.name for item in labeled_data_root.glob('train/*')])

    CLASS_NAMES = class_names
    NUMBER_CLASSES = len(class_names)

    model_class_names = list(class_names)
    handle = open(record_dir+"/model_class_names.pkl", 'wb')
    pickle.dump(model_class_names, handle)
    
    dataset = {'train': str(labeled_data_root/'train'/'*/*.*g'),
          'test': str(labeled_data_root/'test'/'*/*.*g'),
          'val': str(labeled_data_root/'val'/'*/*.*g')}

    DATASET_SIZE_TRAIN = len(list(glob.glob(dataset["train"])))
    DATASET_SIZE_TEST = len(list(glob.glob(dataset["test"])))
    DATASET_SIZE_VAL = len(list(glob.glob(dataset["val"])))
    
    for split in dataset:
        dataset[split] = tf.data.Dataset.list_files(dataset[split],
                                    shuffle=True,
                                    seed=tf.constant(1500, tf.int64)
                                    )
    
    # Map labels with the images from tf.dataset to create "train", "test", "val" datasets
    for split in dataset:
        dataset[split] = dataset[split].map(load_label_images, num_parallel_calls=AUTOTUNE)
    
    RAW_TRAIN_DATASET = dataset["train"] # Clean dataset of the "train" split
    
    print("[INFO] loading the dataset...")

    # training dataset split will go through a resample, suffle, repeat, data augment,
    # and prefetched phase
    dataset["train"] = resample(dataset["train"])
    dataset["train"] = (
      dataset["train"]
      .shuffle(buffer_size=3000, seed=tf.constant(1500, tf.int64))
      .repeat()
      .map(dataset_augmentation(), num_parallel_calls=AUTOTUNE)
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    # testing dataset split will go through a caching, suffle, repeat,
    # and prefetched phase
    cache_string = "{}/{}_{}".format(cache_dir, 128, "test")
    dataset["test"] = (
      dataset["test"]
      .cache(cache_string)
      .shuffle(buffer_size=3000, seed=tf.constant(1500, tf.int64))
      .repeat()
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    # testing dataset split will go through a caching, suffle, repeat,
    # and prefetched phase
    cache_string = "{}/{}_{}".format(cache_dir, 128, "val")
    dataset["val"] = (
      dataset["val"]
      .cache(cache_string)
      .shuffle(buffer_size=3000, seed=tf.constant(1500, tf.int64))
      .repeat()
      .batch(BATCH_SIZE, drop_remainder=False)
      .prefetch(buffer_size=AUTOTUNE)
    )

    print("[INFO] train, test and val datasets created")

    STEPS_TRAIN = DATASET_SIZE_TRAIN//BATCH_SIZE
    STEPS_TEST = DATASET_SIZE_TEST//BATCH_SIZE
    STEPS_VAL = DATASET_SIZE_VAL//BATCH_SIZE
    
    return dataset

# %%
# Method used to count the sample count in a class
def count_class_samples(dataset, num_classes):
    count = np.zeros(num_classes) # returns a new array with zeros according to the class count
    for img, lab in dataset:
        count[lab] += 1
    return count

# %% [markdown]
# Resample Dataset

# %%
# Method used to resample the dataset. This is a solution of highly imbalanced problem
def resample(dataset):

    datasets = []
    cache_dir = './cache/{}_resampled_{}/'.format(128, 'train')
    pathlib.Path(cache_dir).mkdir(parents=True, exist_ok=True) # create cache directory
    
    for i in range(NUMBER_CLASSES): # NUMBER_CLASSES = 23
        data = dataset.filter(lambda img, lab: lab==i)
        data = data.cache(cache_dir+'{}_dataset'.format(i))
        
        data = data.repeat()
        datasets.append(data)
    
    target_dist = [ 1.0/NUMBER_CLASSES ] * NUMBER_CLASSES
    # samples elements from the datasets in the array datasets at randomly
    balanced_dataset = tf.data.experimental.sample_from_datasets(datasets, weights=target_dist, seed=1500)
    
    return balanced_dataset

# %% [markdown]
# Data Augmentation

# %%
# Method to image augment the dataset
def dataset_augmentation():

    tf.random.set_seed(1500) # global seed
    
    def image_augment(image, label):

        degree = tf.random.normal([])*360
        image = tfa.image.rotate(image, degree * math.pi / 180, interpolation='BILINEAR')
        image = tf.image.resize_with_crop_or_pad(image, 138, 138)
        image = tf.image.random_crop(image, (128, 128, 3), seed=1500)
        image = tf.image.random_brightness(image, max_delta=0.2, seed=1500)
        image = tf.image.random_saturation(image, lower=0.5, upper=1.5, seed=1500)
        image = tf.image.random_hue(image, max_delta=0.2, seed=1500)
        image = tf.image.random_contrast(image, lower=0.5, upper=1.5, seed=1500)
        image = tf.image.random_flip_left_right(image, seed=1500)
        image = tf.image.random_flip_up_down(image, seed=1500)

        # The random_* ops do not necessarily clamp.
        # Here it clip tensors value to min 0 and max 1
        image = tf.clip_by_value(image, 0.0, 1.0)
        return image, label
    
    return image_augment

# %%
dataset = build_datasets()
# Out:
# [INFO] loading the dataset...
# WARNING:tensorflow:From <ipython-input-14-039dc184bc79>:16: sample_from_datasets_v2 (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.sample_from_datasets(...)`.
# [INFO] train, test and val datasets created

# %% [markdown]
# # Load unlabelled dataset

# %%
# Method to load the unlabelled data
def load_unlab_images(image_path):
    # read the image from database, decode it, convert the data type to
	  # floating point, and then resize it
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [128, 128])

    # obtain filename
    filename = tf.strings.split(image_path, os.path.sep)[-1]
    return image, filename

def create_unlab_dataset():

  global DATASET_SIZE_UNLAB

  unlab_data_root = pathlib.Path('/content/unlabeled-images/images')

  DATASET_SIZE_UNLAB = len(list(unlab_data_root.glob('*.*g')))

  files_string = str(unlab_data_root/'*.*g')
  list_dataset_unlabeled = tf.data.Dataset.list_files(
          files_string, 
          shuffle=True, 
          seed=tf.constant(1500, tf.int64)
  )
  
  unlab_dataset = list_dataset_unlabeled.map(load_unlab_images, num_parallel_calls=AUTOTUNE)

  print ("Loaded {} images into unlabeled_dataset.".format(DATASET_SIZE_UNLAB))
  
  return unlab_dataset

# %%
dataset["unlab"] = create_unlab_dataset()
# Out:
# Loaded 99417 images into unlabeled_dataset.

# %% [markdown]
# # Define the Hybrid Ensemble model used for labelled data

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPool2D, Multiply, Concatenate, Input, Dropout, ZeroPadding2D, Flatten
from tensorflow.keras import backend as K
from keras.layers import concatenate

datasets_bin = [count_class_samples( RAW_TRAIN_DATASET, NUMBER_CLASSES)]
dataset["mix_train"] = RAW_TRAIN_DATASET

# Method to define all the algorithms used for the architecture
def define_all_models():
    all_models = list()

    inputs = Input(batch_shape=(None, None, None, 3))

    base_model1 = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(
        weights='imagenet', 
        include_top=False, 
        input_shape=(128, 128, 3),
        input_tensor=inputs
    )

    all_models.append(base_model1)

    base_model2 = tf.keras.applications.resnet50.ResNet50(
        weights='imagenet', 
        include_top=False, 
        input_shape=(128, 128, 3),
        input_tensor=inputs
    )

    all_models.append(base_model2)
    return all_models, inputs

# Create the final architecture
def model_define():

    models, inputs = define_all_models()

    for i in range(len(models)):
      model = models[i]
      for layer in model.layers:
        layer._name = 'ensemble_' + layer.name + str('_model_') + str(i + 1)
    
    print(models[0].output.shape)
    print(models[1].output.shape)

    out1 = models[0].output
    out1 = ZeroPadding2D(((0,2), (0,2)))(out1) # Zero-padding layer for 2D input 
    
    outputs = concatenate([out1, models[1].output])

    # used for global average pooling operation for spatial data.
    z = GlobalAveragePooling2D()(outputs) 
    z = Flatten()(z) # newly added
    z = Dropout(0.3)(z)  # to prevent overfitting
    z = Dense(28, activation='relu')(z) # relu to overcome gradient decent problem 
    z = Dense(3584, activation='sigmoid')(z)
    z = Multiply()([outputs, z])
    z = GlobalAveragePooling2D()(z)
    z = Dense(NUMBER_CLASSES, activation="softmax")(z) # "Softmax" Activation layer for classification

    model = Model(inputs=inputs, outputs=z) 

    # plot_model(model, show_shapes=True, to_file='ensemble_models.png')
    
    model.compile(
        optimizer=Adam(learning_rate=0.001), # Good with sparse data
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    
    model.summary()
    
    return model

# %%
model = model_define()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# 219070464/219055592 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# (None, None, None, 1536)
# (None, None, None, 2048)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ensemble_ensemble_input_1_mode  [(None, None, None,  0          []
#  l_1_model_2 (InputLayer)        3)]
#
#  ensemble_conv2d_model_1 (Conv2  (None, None, None,   864        ['ensemble_ensemble_input_1_model
#  D)                             32)                              _1_model_2[0][0]']
#
#  ensemble_batch_normalization_m  (None, None, None,   96         ['ensemble_conv2d_model_1[0][0]']
#  odel_1 (BatchNormalization)    32)
#
#  ensemble_activation_model_1 (A  (None, None, None,   0          ['ensemble_batch_normalization_mo
#  ctivation)                     32)                              del_1[0][0]']
#
#  ensemble_conv2d_1_model_1 (Con  (None, None, None,   9216       ['ensemble_activation_model_1[0][
#  v2D)                           32)                              0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_1_model_1[0][0]
#  _model_1 (BatchNormalization)  32)                              ']
#
#  ensemble_activation_1_model_1   (None, None, None,   0          ['ensemble_batch_normalization_1_
#  (Activation)                   32)                              model_1[0][0]']
#
#  ensemble_conv2d_2_model_1 (Con  (None, None, None,   18432      ['ensemble_activation_1_model_1[0
#  v2D)                           64)                              ][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   192        ['ensemble_conv2d_2_model_1[0][0]
#  _model_1 (BatchNormalization)  64)                              ']
#
#  ensemble_activation_2_model_1   (None, None, None,   0          ['ensemble_batch_normalization_2_
#  (Activation)                   64)                              model_1[0][0]']
#
#  ensemble_max_pooling2d_model_1  (None, None, None,   0          ['ensemble_activation_2_model_1[0
#   (MaxPooling2D)                64)                              ][0]']
#
#  ensemble_conv2d_3_model_1 (Con  (None, None, None,   5120       ['ensemble_max_pooling2d_model_1[
#  v2D)                           80)                              0][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   240        ['ensemble_conv2d_3_model_1[0][0]
#  _model_1 (BatchNormalization)  80)                              ']
#
#  ensemble_activation_3_model_1   (None, None, None,   0          ['ensemble_batch_normalization_3_
#  (Activation)                   80)                              model_1[0][0]']
#
#  ensemble_conv2d_4_model_1 (Con  (None, None, None,   138240     ['ensemble_activation_3_model_1[0
#  v2D)                           192)                             ][0]']
#
#  ensemble_batch_normalization_4  (None, None, None,   576        ['ensemble_conv2d_4_model_1[0][0]
#  _model_1 (BatchNormalization)  192)                             ']
#
#  ensemble_activation_4_model_1   (None, None, None,   0          ['ensemble_batch_normalization_4_
#  (Activation)                   192)                             model_1[0][0]']
#
#  ensemble_max_pooling2d_1_model  (None, None, None,   0          ['ensemble_activation_4_model_1[0
#  _1 (MaxPooling2D)              192)                             ][0]']
#
#  ensemble_conv2d_8_model_1 (Con  (None, None, None,   12288      ['ensemble_max_pooling2d_1_model_
#  v2D)                           64)                              1[0][0]']
#
#  ensemble_batch_normalization_8  (None, None, None,   192        ['ensemble_conv2d_8_model_1[0][0]
#  _model_1 (BatchNormalization)  64)                              ']
#
#  ensemble_activation_8_model_1   (None, None, None,   0          ['ensemble_batch_normalization_8_
#  (Activation)                   64)                              model_1[0][0]']
#
#  ensemble_conv2d_6_model_1 (Con  (None, None, None,   9216       ['ensemble_max_pooling2d_1_model_
#  v2D)                           48)                              1[0][0]']
#
#  ensemble_conv2d_9_model_1 (Con  (None, None, None,   55296      ['ensemble_activation_8_model_1[0
#  v2D)                           96)                              ][0]']
#
#  ensemble_batch_normalization_6  (None, None, None,   144        ['ensemble_conv2d_6_model_1[0][0]
#  _model_1 (BatchNormalization)  48)                              ']
#
#  ensemble_batch_normalization_9  (None, None, None,   288        ['ensemble_conv2d_9_model_1[0][0]
#  _model_1 (BatchNormalization)  96)                              ']
#
#  ensemble_activation_6_model_1   (None, None, None,   0          ['ensemble_batch_normalization_6_
#  (Activation)                   48)                              model_1[0][0]']
#
#  ensemble_activation_9_model_1   (None, None, None,   0          ['ensemble_batch_normalization_9_
#  (Activation)                   96)                              model_1[0][0]']
#
#  ensemble_average_pooling2d_mod  (None, None, None,   0          ['ensemble_max_pooling2d_1_model_
#  el_1 (AveragePooling2D)        192)                             1[0][0]']
#
#  ensemble_conv2d_5_model_1 (Con  (None, None, None,   18432      ['ensemble_max_pooling2d_1_model_
#  v2D)                           96)                              1[0][0]']
#
#  ensemble_conv2d_7_model_1 (Con  (None, None, None,   76800      ['ensemble_activation_6_model_1[0
#  v2D)                           64)                              ][0]']
#
#  ensemble_conv2d_10_model_1 (Co  (None, None, None,   82944      ['ensemble_activation_9_model_1[0
#  nv2D)                          96)                              ][0]']
#
#  ensemble_conv2d_11_model_1 (Co  (None, None, None,   12288      ['ensemble_average_pooling2d_mode
#  nv2D)                          64)                              l_1[0][0]']
#
#  ensemble_batch_normalization_5  (None, None, None,   288        ['ensemble_conv2d_5_model_1[0][0]
#  _model_1 (BatchNormalization)  96)                              ']
#
#  ensemble_batch_normalization_7  (None, None, None,   192        ['ensemble_conv2d_7_model_1[0][0]
#  _model_1 (BatchNormalization)  64)                              ']
#
#  ensemble_batch_normalization_1  (None, None, None,   288        ['ensemble_conv2d_10_model_1[0][0
#  0_model_1 (BatchNormalization)  96)                             ]']
#
#  ensemble_batch_normalization_1  (None, None, None,   192        ['ensemble_conv2d_11_model_1[0][0
#  1_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_5_model_1   (None, None, None,   0          ['ensemble_batch_normalization_5_
#  (Activation)                   96)                              model_1[0][0]']
#
#  ensemble_activation_7_model_1   (None, None, None,   0          ['ensemble_batch_normalization_7_
#  (Activation)                   64)                              model_1[0][0]']
#
#  ensemble_activation_10_model_1  (None, None, None,   0          ['ensemble_batch_normalization_10
#   (Activation)                  96)                              _model_1[0][0]']
#
#  ensemble_activation_11_model_1  (None, None, None,   0          ['ensemble_batch_normalization_11
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_mixed_5b_model_1 (Con  (None, None, None,   0          ['ensemble_activation_5_model_1[0
#  catenate)                      320)                             ][0]',
#                                                                   'ensemble_activation_7_model_1[0
#                                                                  ][0]',
#                                                                   'ensemble_activation_10_model_1[
#                                                                  0][0]',
#                                                                   'ensemble_activation_11_model_1[
#                                                                  0][0]']
#
#  ensemble_conv2d_15_model_1 (Co  (None, None, None,   10240      ['ensemble_mixed_5b_model_1[0][0]
#  nv2D)                          32)                              ']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_15_model_1[0][0
#  5_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_activation_15_model_1  (None, None, None,   0          ['ensemble_batch_normalization_15
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_conv2d_13_model_1 (Co  (None, None, None,   10240      ['ensemble_mixed_5b_model_1[0][0]
#  nv2D)                          32)                              ']
#
#  ensemble_conv2d_16_model_1 (Co  (None, None, None,   13824      ['ensemble_activation_15_model_1[
#  nv2D)                          48)                              0][0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_13_model_1[0][0
#  3_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_1  (None, None, None,   144        ['ensemble_conv2d_16_model_1[0][0
#  6_model_1 (BatchNormalization)  48)                             ]']
#
#  ensemble_activation_13_model_1  (None, None, None,   0          ['ensemble_batch_normalization_13
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_16_model_1  (None, None, None,   0          ['ensemble_batch_normalization_16
#   (Activation)                  48)                              _model_1[0][0]']
#
#  ensemble_conv2d_12_model_1 (Co  (None, None, None,   10240      ['ensemble_mixed_5b_model_1[0][0]
#  nv2D)                          32)                              ']
#
#  ensemble_conv2d_14_model_1 (Co  (None, None, None,   9216       ['ensemble_activation_13_model_1[
#  nv2D)                          32)                              0][0]']
#
#  ensemble_conv2d_17_model_1 (Co  (None, None, None,   27648      ['ensemble_activation_16_model_1[
#  nv2D)                          64)                              0][0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_12_model_1[0][0
#  2_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_14_model_1[0][0
#  4_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_1  (None, None, None,   192        ['ensemble_conv2d_17_model_1[0][0
#  7_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_12_model_1  (None, None, None,   0          ['ensemble_batch_normalization_12
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_14_model_1  (None, None, None,   0          ['ensemble_batch_normalization_14
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_17_model_1  (None, None, None,   0          ['ensemble_batch_normalization_17
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_block35_1_mixed_model  (None, None, None,   0          ['ensemble_activation_12_model_1[
#  _1 (Concatenate)               128)                             0][0]',
#                                                                   'ensemble_activation_14_model_1[
#                                                                  0][0]',
#                                                                   'ensemble_activation_17_model_1[
#                                                                  0][0]']
#
#  ensemble_block35_1_conv_model_  (None, None, None,   41280      ['ensemble_block35_1_mixed_model_
#  1 (Conv2D)                     320)                             1[0][0]']
#
#  ensemble_block35_1_model_1 (La  (None, None, None,   0          ['ensemble_mixed_5b_model_1[0][0]
#  mbda)                          320)                             ',
#                                                                   'ensemble_block35_1_conv_model_1
#                                                                  [0][0]']
#
#  ensemble_block35_1_ac_model_1   (None, None, None,   0          ['ensemble_block35_1_model_1[0][0
#  (Activation)                   320)                             ]']
#
#  ensemble_conv2d_21_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_1_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_21_model_1[0][0
#  1_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_activation_21_model_1  (None, None, None,   0          ['ensemble_batch_normalization_21
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_conv2d_19_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_1_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_22_model_1 (Co  (None, None, None,   13824      ['ensemble_activation_21_model_1[
#  nv2D)                          48)                              0][0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_19_model_1[0][0
#  9_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   144        ['ensemble_conv2d_22_model_1[0][0
#  2_model_1 (BatchNormalization)  48)                             ]']
#
#  ensemble_activation_19_model_1  (None, None, None,   0          ['ensemble_batch_normalization_19
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_22_model_1  (None, None, None,   0          ['ensemble_batch_normalization_22
#   (Activation)                  48)                              _model_1[0][0]']
#
#  ensemble_conv2d_18_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_1_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_20_model_1 (Co  (None, None, None,   9216       ['ensemble_activation_19_model_1[
#  nv2D)                          32)                              0][0]']
#
#  ensemble_conv2d_23_model_1 (Co  (None, None, None,   27648      ['ensemble_activation_22_model_1[
#  nv2D)                          64)                              0][0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   96         ['ensemble_conv2d_18_model_1[0][0
#  8_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_20_model_1[0][0
#  0_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   192        ['ensemble_conv2d_23_model_1[0][0
#  3_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_18_model_1  (None, None, None,   0          ['ensemble_batch_normalization_18
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_20_model_1  (None, None, None,   0          ['ensemble_batch_normalization_20
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_23_model_1  (None, None, None,   0          ['ensemble_batch_normalization_23
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_block35_2_mixed_model  (None, None, None,   0          ['ensemble_activation_18_model_1[
#  _1 (Concatenate)               128)                             0][0]',
#                                                                   'ensemble_activation_20_model_1[
#                                                                  0][0]',
#                                                                   'ensemble_activation_23_model_1[
#                                                                  0][0]']
#
#  ensemble_block35_2_conv_model_  (None, None, None,   41280      ['ensemble_block35_2_mixed_model_
#  1 (Conv2D)                     320)                             1[0][0]']
#
#  ensemble_block35_2_model_1 (La  (None, None, None,   0          ['ensemble_block35_1_ac_model_1[0
#  mbda)                          320)                             ][0]',
#                                                                   'ensemble_block35_2_conv_model_1
#                                                                  [0][0]']
#
#  ensemble_block35_2_ac_model_1   (None, None, None,   0          ['ensemble_block35_2_model_1[0][0
#  (Activation)                   320)                             ]']
#
#  ensemble_conv2d_27_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_2_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_27_model_1[0][0
#  7_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_activation_27_model_1  (None, None, None,   0          ['ensemble_batch_normalization_27
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_conv2d_25_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_2_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_28_model_1 (Co  (None, None, None,   13824      ['ensemble_activation_27_model_1[
#  nv2D)                          48)                              0][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_25_model_1[0][0
#  5_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   144        ['ensemble_conv2d_28_model_1[0][0
#  8_model_1 (BatchNormalization)  48)                             ]']
#
#  ensemble_activation_25_model_1  (None, None, None,   0          ['ensemble_batch_normalization_25
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_28_model_1  (None, None, None,   0          ['ensemble_batch_normalization_28
#   (Activation)                  48)                              _model_1[0][0]']
#
#  ensemble_conv2d_24_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_2_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_26_model_1 (Co  (None, None, None,   9216       ['ensemble_activation_25_model_1[
#  nv2D)                          32)                              0][0]']
#
#  ensemble_conv2d_29_model_1 (Co  (None, None, None,   27648      ['ensemble_activation_28_model_1[
#  nv2D)                          64)                              0][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_24_model_1[0][0
#  4_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   96         ['ensemble_conv2d_26_model_1[0][0
#  6_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_2  (None, None, None,   192        ['ensemble_conv2d_29_model_1[0][0
#  9_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_24_model_1  (None, None, None,   0          ['ensemble_batch_normalization_24
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_26_model_1  (None, None, None,   0          ['ensemble_batch_normalization_26
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_29_model_1  (None, None, None,   0          ['ensemble_batch_normalization_29
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_block35_3_mixed_model  (None, None, None,   0          ['ensemble_activation_24_model_1[
#  _1 (Concatenate)               128)                             0][0]',
#                                                                   'ensemble_activation_26_model_1[
#                                                                  0][0]',
#                                                                   'ensemble_activation_29_model_1[
#                                                                  0][0]']
#
#  ensemble_block35_3_conv_model_  (None, None, None,   41280      ['ensemble_block35_3_mixed_model_
#  1 (Conv2D)                     320)                             1[0][0]']
#
#  ensemble_block35_3_model_1 (La  (None, None, None,   0          ['ensemble_block35_2_ac_model_1[0
#  mbda)                          320)                             ][0]',
#                                                                   'ensemble_block35_3_conv_model_1
#                                                                  [0][0]']
#
#  ensemble_block35_3_ac_model_1   (None, None, None,   0          ['ensemble_block35_3_model_1[0][0
#  (Activation)                   320)                             ]']
#
#  ensemble_conv2d_33_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_3_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_33_model_1[0][0
#  3_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_activation_33_model_1  (None, None, None,   0          ['ensemble_batch_normalization_33
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_conv2d_31_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_3_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_34_model_1 (Co  (None, None, None,   13824      ['ensemble_activation_33_model_1[
#  nv2D)                          48)                              0][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_31_model_1[0][0
#  1_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_3  (None, None, None,   144        ['ensemble_conv2d_34_model_1[0][0
#  4_model_1 (BatchNormalization)  48)                             ]']
#
#  ensemble_activation_31_model_1  (None, None, None,   0          ['ensemble_batch_normalization_31
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_34_model_1  (None, None, None,   0          ['ensemble_batch_normalization_34
#   (Activation)                  48)                              _model_1[0][0]']
#
#  ensemble_conv2d_30_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_3_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_32_model_1 (Co  (None, None, None,   9216       ['ensemble_activation_31_model_1[
#  nv2D)                          32)                              0][0]']
#
#  ensemble_conv2d_35_model_1 (Co  (None, None, None,   27648      ['ensemble_activation_34_model_1[
#  nv2D)                          64)                              0][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_30_model_1[0][0
#  0_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_32_model_1[0][0
#  2_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_3  (None, None, None,   192        ['ensemble_conv2d_35_model_1[0][0
#  5_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_30_model_1  (None, None, None,   0          ['ensemble_batch_normalization_30
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_32_model_1  (None, None, None,   0          ['ensemble_batch_normalization_32
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_35_model_1  (None, None, None,   0          ['ensemble_batch_normalization_35
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_block35_4_mixed_model  (None, None, None,   0          ['ensemble_activation_30_model_1[
#  _1 (Concatenate)               128)                             0][0]',
#                                                                   'ensemble_activation_32_model_1[
#                                                                  0][0]',
#                                                                   'ensemble_activation_35_model_1[
#                                                                  0][0]']
#
#  ensemble_block35_4_conv_model_  (None, None, None,   41280      ['ensemble_block35_4_mixed_model_
#  1 (Conv2D)                     320)                             1[0][0]']
#
#  ensemble_block35_4_model_1 (La  (None, None, None,   0          ['ensemble_block35_3_ac_model_1[0
#  mbda)                          320)                             ][0]',
#                                                                   'ensemble_block35_4_conv_model_1
#                                                                  [0][0]']
#
#  ensemble_block35_4_ac_model_1   (None, None, None,   0          ['ensemble_block35_4_model_1[0][0
#  (Activation)                   320)                             ]']
#
#  ensemble_conv2d_39_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_4_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_39_model_1[0][0
#  9_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_activation_39_model_1  (None, None, None,   0          ['ensemble_batch_normalization_39
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_conv2d_37_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_4_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_40_model_1 (Co  (None, None, None,   13824      ['ensemble_activation_39_model_1[
#  nv2D)                          48)                              0][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_37_model_1[0][0
#  7_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_4  (None, None, None,   144        ['ensemble_conv2d_40_model_1[0][0
#  0_model_1 (BatchNormalization)  48)                             ]']
#
#  ensemble_activation_37_model_1  (None, None, None,   0          ['ensemble_batch_normalization_37
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_40_model_1  (None, None, None,   0          ['ensemble_batch_normalization_40
#   (Activation)                  48)                              _model_1[0][0]']
#
#  ensemble_conv2d_36_model_1 (Co  (None, None, None,   10240      ['ensemble_block35_4_ac_model_1[0
#  nv2D)                          32)                              ][0]']
#
#  ensemble_conv2d_38_model_1 (Co  (None, None, None,   9216       ['ensemble_activation_37_model_1[
#  nv2D)                          32)                              0][0]']
#
#  ensemble_conv2d_41_model_1 (Co  (None, None, None,   27648      ['ensemble_activation_40_model_1[
#  nv2D)                          64)                              0][0]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_36_model_1[0][0
#  6_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_3  (None, None, None,   96         ['ensemble_conv2d_38_model_1[0][0
#  8_model_1 (BatchNormalization)  32)                             ]']
#
#  ensemble_batch_normalization_4  (None, None, None,   192        ['ensemble_conv2d_41_model_1[0][0
#  1_model_1 (BatchNormalization)  64)                             ]']
#
#  ensemble_activation_36_model_1  (None, None, None,   0          ['ensemble_batch_normalization_36
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_38_model_1  (None, None, None,   0          ['ensemble_batch_normalization_38
#   (Activation)                  32)                              _model_1[0][0]']
#
#  ensemble_activation_41_model_1  (None, None, None,   0          ['ensemble_batch_normalization_41
#   (Activation)                  64)                              _model_1[0][0]']
#
#  ensemble_block35_5_mixed_model  (None, None, None,   0          ['ensemble_activation_36_model_1[
#  _1 (Concatenate)               128)                             0][0]',
#                                                                   'ensemble_activation_38_model_1[
#                                                                  0][0]',
# ...
#  el_2 (BatchNormalization)      512)                             del_2[0][0]']
#
#  ensemble_block8_9_model_1 (Lam  (None, None, None,   0          ['ensemble_block8_8_ac_model_1[0]
#  bda)                           2080)                            [0]',
#                                                                   'ensemble_block8_9_conv_model_1[
#                                                                  0][0]']
#
#  ensemble_conv5_block2_1_relu_m  (None, None, None,   0          ['ensemble_conv5_block2_1_bn_mode
#  odel_2 (Activation)            512)                             l_2[0][0]']
#
#  ensemble_block8_9_ac_model_1 (  (None, None, None,   0          ['ensemble_block8_9_model_1[0][0]
#  Activation)                    2080)                            ']
#
#  ensemble_conv5_block2_2_conv_m  (None, None, None,   2359808    ['ensemble_conv5_block2_1_relu_mo
#  odel_2 (Conv2D)                512)                             del_2[0][0]']
#
#  ensemble_conv2d_200_model_1 (C  (None, None, None,   399360     ['ensemble_block8_9_ac_model_1[0]
#  onv2D)                         192)                             [0]']
#
#  ensemble_conv5_block2_2_bn_mod  (None, None, None,   2048       ['ensemble_conv5_block2_2_conv_mo
#  el_2 (BatchNormalization)      512)                             del_2[0][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   576        ['ensemble_conv2d_200_model_1[0][
#  00_model_1 (BatchNormalization  192)                            0]']
#  )
#
#  ensemble_conv5_block2_2_relu_m  (None, None, None,   0          ['ensemble_conv5_block2_2_bn_mode
#  odel_2 (Activation)            512)                             l_2[0][0]']
#
#  ensemble_activation_200_model_  (None, None, None,   0          ['ensemble_batch_normalization_20
#  1 (Activation)                 192)                             0_model_1[0][0]']
#
#  ensemble_conv5_block2_3_conv_m  (None, None, None,   1050624    ['ensemble_conv5_block2_2_relu_mo
#  odel_2 (Conv2D)                2048)                            del_2[0][0]']
#
#  ensemble_conv2d_201_model_1 (C  (None, None, None,   129024     ['ensemble_activation_200_model_1
#  onv2D)                         224)                             [0][0]']
#
#  ensemble_conv5_block2_3_bn_mod  (None, None, None,   8192       ['ensemble_conv5_block2_3_conv_mo
#  el_2 (BatchNormalization)      2048)                            del_2[0][0]']
#
#  ensemble_batch_normalization_2  (None, None, None,   672        ['ensemble_conv2d_201_model_1[0][
#  01_model_1 (BatchNormalization  224)                            0]']
#  )
#
#  ensemble_conv5_block2_add_mode  (None, None, None,   0          ['ensemble_conv5_block1_out_model
#  l_2 (Add)                      2048)                            _2[0][0]',
#                                                                   'ensemble_conv5_block2_3_bn_mode
#                                                                  l_2[0][0]']
#
#  ensemble_activation_201_model_  (None, None, None,   0          ['ensemble_batch_normalization_20
#  1 (Activation)                 224)                             1_model_1[0][0]']
#
#  ensemble_conv5_block2_out_mode  (None, None, None,   0          ['ensemble_conv5_block2_add_model
#  l_2 (Activation)               2048)                            _2[0][0]']
#
#  ensemble_conv2d_199_model_1 (C  (None, None, None,   399360     ['ensemble_block8_9_ac_model_1[0]
#  onv2D)                         192)                             [0]']
#
#  ensemble_conv2d_202_model_1 (C  (None, None, None,   172032     ['ensemble_activation_201_model_1
#  onv2D)                         256)                             [0][0]']
#
#  ensemble_conv5_block3_1_conv_m  (None, None, None,   1049088    ['ensemble_conv5_block2_out_model
#  odel_2 (Conv2D)                512)                             _2[0][0]']
#
#  ensemble_batch_normalization_1  (None, None, None,   576        ['ensemble_conv2d_199_model_1[0][
#  99_model_1 (BatchNormalization  192)                            0]']
#  )
#
#  ensemble_batch_normalization_2  (None, None, None,   768        ['ensemble_conv2d_202_model_1[0][
#  02_model_1 (BatchNormalization  256)                            0]']
#  )
#
#  ensemble_conv5_block3_1_bn_mod  (None, None, None,   2048       ['ensemble_conv5_block3_1_conv_mo
#  el_2 (BatchNormalization)      512)                             del_2[0][0]']
#
#  ensemble_activation_199_model_  (None, None, None,   0          ['ensemble_batch_normalization_19
#  1 (Activation)                 192)                             9_model_1[0][0]']
#
#  ensemble_activation_202_model_  (None, None, None,   0          ['ensemble_batch_normalization_20
#  1 (Activation)                 256)                             2_model_1[0][0]']
#
#  ensemble_conv5_block3_1_relu_m  (None, None, None,   0          ['ensemble_conv5_block3_1_bn_mode
#  odel_2 (Activation)            512)                             l_2[0][0]']
#
#  ensemble_block8_10_mixed_model  (None, None, None,   0          ['ensemble_activation_199_model_1
#  _1 (Concatenate)               448)                             [0][0]',
#                                                                   'ensemble_activation_202_model_1
#                                                                  [0][0]']
#
#  ensemble_conv5_block3_2_conv_m  (None, None, None,   2359808    ['ensemble_conv5_block3_1_relu_mo
#  odel_2 (Conv2D)                512)                             del_2[0][0]']
#
#  ensemble_block8_10_conv_model_  (None, None, None,   933920     ['ensemble_block8_10_mixed_model_
#  1 (Conv2D)                     2080)                            1[0][0]']
#
#  ensemble_conv5_block3_2_bn_mod  (None, None, None,   2048       ['ensemble_conv5_block3_2_conv_mo
#  el_2 (BatchNormalization)      512)                             del_2[0][0]']
#
#  ensemble_block8_10_model_1 (La  (None, None, None,   0          ['ensemble_block8_9_ac_model_1[0]
#  mbda)                          2080)                            [0]',
#                                                                   'ensemble_block8_10_conv_model_1
#                                                                  [0][0]']
#
#  ensemble_conv5_block3_2_relu_m  (None, None, None,   0          ['ensemble_conv5_block3_2_bn_mode
#  odel_2 (Activation)            512)                             l_2[0][0]']
#
#  ensemble_conv_7b_model_1 (Conv  (None, None, None,   3194880    ['ensemble_block8_10_model_1[0][0
#  2D)                            1536)                            ]']
#
#  ensemble_conv5_block3_3_conv_m  (None, None, None,   1050624    ['ensemble_conv5_block3_2_relu_mo
#  odel_2 (Conv2D)                2048)                            del_2[0][0]']
#
#  ensemble_conv_7b_bn_model_1 (B  (None, None, None,   4608       ['ensemble_conv_7b_model_1[0][0]'
#  atchNormalization)             1536)                            ]
#
#  ensemble_conv5_block3_3_bn_mod  (None, None, None,   8192       ['ensemble_conv5_block3_3_conv_mo
#  el_2 (BatchNormalization)      2048)                            del_2[0][0]']
#
#  ensemble_conv_7b_ac_model_1 (A  (None, None, None,   0          ['ensemble_conv_7b_bn_model_1[0][
#  ctivation)                     1536)                            0]']
#
#  ensemble_conv5_block3_add_mode  (None, None, None,   0          ['ensemble_conv5_block2_out_model
#  l_2 (Add)                      2048)                            _2[0][0]',
#                                                                   'ensemble_conv5_block3_3_bn_mode
#                                                                  l_2[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, None, None,   0          ['ensemble_conv_7b_ac_model_1[0][
#                                 1536)                            0]']
#
#  ensemble_conv5_block3_out_mode  (None, None, None,   0          ['ensemble_conv5_block3_add_model
#  l_2 (Activation)               2048)                            _2[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['zero_padding2d[0][0]',
#                                 3584)                             'ensemble_conv5_block3_out_model
#                                                                  _2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 3584)        0           ['concatenate[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 3584)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 3584)         0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 28)           100380      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 3584)         103936      ['dense[0][0]']
#
#  multiply (Multiply)            (None, None, None,   0           ['concatenate[0][0]',
#                                 3584)                             'dense_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 3584)        0           ['multiply[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 23)           82455       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 78,211,219
# Trainable params: 78,097,555
# Non-trainable params: 113,664
# __________________________________________________________________________________________________

# %% [markdown]
# # Train the model for labelled data

# %%
start = time.time()

model_train = model.fit(
        dataset["train"],
        steps_per_epoch = STEPS_TRAIN,
        epochs = 15,
        validation_data = dataset["val"],
        validation_steps = STEPS_VAL,
        validation_freq = 1,
        verbose = 1
)

print ("Total time:", (np.round(time.time() - start, 4)/60), "minutes.")
# Out:
# Epoch 1/15
# 931/931 [==============================] - 258s 194ms/step - loss: 1.9230 - sparse_categorical_accuracy: 0.3476 - val_loss: 1.7339 - val_sparse_categorical_accuracy: 0.4608
# Epoch 2/15
# 931/931 [==============================] - 174s 187ms/step - loss: 1.2500 - sparse_categorical_accuracy: 0.5537 - val_loss: 1.2230 - val_sparse_categorical_accuracy: 0.6262
# Epoch 3/15
# 931/931 [==============================] - 159s 171ms/step - loss: 0.9825 - sparse_categorical_accuracy: 0.6496 - val_loss: 1.0857 - val_sparse_categorical_accuracy: 0.6654
# Epoch 4/15
# 931/931 [==============================] - 160s 171ms/step - loss: 0.8745 - sparse_categorical_accuracy: 0.6869 - val_loss: 1.9848 - val_sparse_categorical_accuracy: 0.6088
# Epoch 5/15
# 931/931 [==============================] - 158s 170ms/step - loss: 0.7490 - sparse_categorical_accuracy: 0.7329 - val_loss: 0.7676 - val_sparse_categorical_accuracy: 0.7637
# Epoch 6/15
# 931/931 [==============================] - 155s 167ms/step - loss: 0.7144 - sparse_categorical_accuracy: 0.7419 - val_loss: 0.9163 - val_sparse_categorical_accuracy: 0.7034
# Epoch 7/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.6277 - sparse_categorical_accuracy: 0.7748 - val_loss: 0.9423 - val_sparse_categorical_accuracy: 0.7170
# Epoch 8/15
# 931/931 [==============================] - 156s 168ms/step - loss: 0.5648 - sparse_categorical_accuracy: 0.8025 - val_loss: 0.5823 - val_sparse_categorical_accuracy: 0.8097
# Epoch 9/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.5555 - sparse_categorical_accuracy: 0.8005 - val_loss: 0.8908 - val_sparse_categorical_accuracy: 0.7320
# Epoch 10/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.4992 - sparse_categorical_accuracy: 0.8193 - val_loss: 0.9851 - val_sparse_categorical_accuracy: 0.7195
# Epoch 11/15
# 931/931 [==============================] - 155s 167ms/step - loss: 0.4921 - sparse_categorical_accuracy: 0.8263 - val_loss: 0.6833 - val_sparse_categorical_accuracy: 0.7879
# Epoch 12/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.4490 - sparse_categorical_accuracy: 0.8324 - val_loss: 0.7616 - val_sparse_categorical_accuracy: 0.7792
# Epoch 13/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.4271 - sparse_categorical_accuracy: 0.8459 - val_loss: 0.7299 - val_sparse_categorical_accuracy: 0.7842
# Epoch 14/15
# 931/931 [==============================] - 156s 167ms/step - loss: 0.4252 - sparse_categorical_accuracy: 0.8471 - val_loss: 0.6135 - val_sparse_categorical_accuracy: 0.8103
# Epoch 15/15
# 931/931 [==============================] - 155s 167ms/step - loss: 0.3775 - sparse_categorical_accuracy: 0.8608 - val_loss: 0.6336 - val_sparse_categorical_accuracy: 0.8141
# Total time: 41.10691666666666 minutes.

# %%
print(model_train.history.keys())
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
def save_model():
  handle = open(record_dir+"/model_train.pkl", 'wb')
  pickle.dump(model_train.history, handle)
  model.save(record_dir+'/model.h5')

# %% [markdown]
# ## Model Evaluation

# %%
def calculate_true_and_predicted_cat(model, dataset):

  # Using test data to evaluate the model
  test_evaluate = model.evaluate(dataset["test"], steps=STEPS_TEST) # steps since tf.dataset
  print("\nTest Accuracy: ", test_evaluate)

  # Find true_categories and predicted_categories
  eval_dataset = dataset["test"].unbatch().take(DATASET_SIZE_TEST)
  eval_dataset = eval_dataset.as_numpy_iterator()
  eval_dataset = np.array(list(eval_dataset))
  true_categories = list(eval_dataset[:,1]) 
  eval_images = np.stack(eval_dataset[:,0], axis=0) # eval_dataset[:,0] = give me the 0th index of all the rows in eval_dataset

  # Create predictions and predicted_categories
  predictions = model.predict(eval_images)
  predicted_categories = [np.argmax(pred) for pred in predictions]

  return true_categories, predicted_categories

def using_evaluation_metrics(model_train, true_categories, predicted_categories):

    sns.set()
    
    # Plot Accuracy
    plot_accuracy(model_train)
    # Plot Loss
    plot_loss(model_train)

    print('\nAccuracy score is :', metrics.accuracy_score(true_categories, predicted_categories))
    print('Precision score is :', metrics.precision_score(true_categories, predicted_categories, average='weighted'))
    print('Recall score is :',metrics.recall_score(true_categories, predicted_categories, average='weighted'))
    print('F1 Score is :', metrics.f1_score(true_categories, predicted_categories,average='weighted'))
    print('Cohen Kappa Score :', metrics.cohen_kappa_score(true_categories, predicted_categories))
    print("MCC :", metrics.matthews_corrcoef(true_categories, predicted_categories))
    
    # Print the Classification report
    print("\nClassification Report: ")
    report = metrics.classification_report( y_true=true_categories, y_pred=predicted_categories,
                labels=range(NUMBER_CLASSES),
                target_names=CLASS_NAMES,
                digits=3,
                zero_division=0)
    print(report)

def plot_confusion_matrix(cm, names=None):

    print('Confusion Matrix')
    
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()

    tick_marks = np.arange(NUMBER_CLASSES)
    plt.xticks(tick_marks, CLASS_NAMES, rotation=90)
    plt.yticks(tick_marks, CLASS_NAMES)

    # normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm = np.around(cm, decimals=2)
    cm[np.isnan(cm)] = 0.0
    print("Normalized confusion matrix")

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True Categories')
    plt.xlabel('Predicted Categories')
    plt.savefig(record_dir+"/confusion_matrix.pdf", format="pdf")
    plt.show()

def plot_accuracy(model_train):
  
  plt.plot(model_train.history['sparse_categorical_accuracy'], label='Training Accuracy')
  plt.plot(model_train.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(loc='upper left')
  plt.show()

def plot_loss(model_train):
  plt.plot(model_train.history['loss'], label='Training Loss')
  plt.plot(model_train.history['val_loss'], label='Validation Loss')
  plt.title('Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(loc='upper left')
  plt.show()

# %%
true_categories, predicted_categories = calculate_true_and_predicted_cat(model, dataset)
using_evaluation_metrics(model_train, true_categories, predicted_categories)

# Plot the Confusion Matrix
cm = metrics.confusion_matrix(true_categories, predicted_categories)
plot_confusion_matrix(cm, CLASS_NAMES)

save_model()
# Out:
# 199/199 [==============================] - 11s 49ms/step - loss: 0.7129 - sparse_categorical_accuracy: 0.7883
#
# Test Accuracy:  [0.7128790616989136, 0.7883166074752808]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   # Remove the CWD from sys.path while we load stuff.
# Accuracy score is : 0.7878598247809763
# Precision score is : 0.8103591220779168
# Recall score is : 0.7878598247809763
# F1 Score is : 0.782139212383037
# Cohen Kappa Score : 0.7701205322361352
# MCC : 0.7719373703041781
#
# Classification Report:
#                               precision    recall  f1-score   support
#
#                       z-line      0.718     0.800     0.757       140
#                        cecum      0.836     0.980     0.902       151
#             retroflex-rectum      0.587     0.915     0.715        59
#                        ileum      0.000     0.000     0.000         1
#                     barretts      0.000     0.000     0.000         6
#                esophagitis-a      0.407     0.400     0.403        60
#       dyed-resection-margins      1.000     0.500     0.667       148
#               impacted-stool      0.556     1.000     0.714        20
# ulcerative-colitis-grade-1-2      0.000     0.000     0.000         2
#   ulcerative-colitis-grade-2      0.477     0.318     0.382        66
#              esophagitis-b-d      0.833     0.256     0.392        39
#                     bbps-0-1      0.927     0.918     0.922        97
#   ulcerative-colitis-grade-1      0.315     0.567     0.405        30
#            retroflex-stomach      0.965     0.957     0.961       115
#                  hemorrhoids      0.000     0.000     0.000         1
#       barretts-short-segment      0.250     0.250     0.250         8
#           dyed-lifted-polyps      0.702     0.847     0.767       150
#                       polyps      0.959     0.909     0.933       154
# ulcerative-colitis-grade-2-3      0.000     0.000     0.000         4
#   ulcerative-colitis-grade-3      0.529     0.450     0.486        20
#                      pylorus      0.919     0.980     0.948       150
#                     bbps-2-3      0.993     0.884     0.935       172
# ulcerative-colitis-grade-0-1      0.300     0.600     0.400         5
#
#                     accuracy                          0.788      1598
#                    macro avg      0.534     0.545     0.519      1598
#                 weighted avg      0.810     0.788     0.782      1598
#
# Confusion Matrix
# Normalized confusion matrix
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Generate pseudo labels on unlabeled images using the previously built model

# %% [markdown]
# ### Generate pseudo labels for the unlabelled dataset

# %%
findings = {
    "prediction_value_list": [], 
    "label_index_list": [], 
    "img_name_list": []
    }

# %%
def generate_pseudo_labels(unlab_dataset, model):

    # Use the unlabeled dataset to generate new psuedo labels
    start = time.time()
    findings_count = 0

    # Show tqdm bars
    predicting_bar = tqdm(total=DATASET_SIZE_UNLAB, desc='Predicting', position=0, initial=0)
    findings_bar = tqdm(total=DATASET_SIZE_UNLAB, desc='Findings', position=1, bar_format='{desc}:{bar}{n_fmt}', initial=0)
    
    # Iterates the images one by one
    for tot_cnt, (image,path) in enumerate(unlab_dataset, start=0):
      if tot_cnt > 20000:
          break
              
      img = np.expand_dims(image, 0)
      prediction = model.predict(img) # returns numpy array(s) of predictions.
      highest_pred = np.max(prediction) # returns the maximum value

      # Check if the highest_pred is more than the threshold value
      if highest_pred > 0.85:
          prediction_index = np.argmax(prediction).astype(np.uint8) # returns the index of the max element

          findings["label_index_list"].append(prediction_index)
          findings["prediction_value_list"].append(highest_pred)
          findings["img_name_list"].append(path)
              
          findings_count += 1
          findings_bar.update(1)
      predicting_bar.update(1)

    # Save the pseudo labels
    handle = open(record_dir+"/pseudo_labels.pkl", 'wb')
    pickle.dump(findings, handle)
        
    print ("\nTotal run time: {:.1f} min.".format( (time.time() - start)/60 ))
    print ("Found {} new samples in unlabeled_dataset after looking at {} images.".format(findings_count, tot_cnt))
        
    return findings

# %%
findings = generate_pseudo_labels(dataset["unlab"], model)
# Out:
# Predicting:   0%|          | 0/99417 [00:00<?, ?it/s]
# Findings:          0
# Total run time: 31.4 min.
# Found 9097 new samples in unlabeled_ds after looking at 20001 images.

# %% [markdown]
# ### Sort the lists from confidence levels highest to lowest

# %%
sorted_list = list(zip(findings["prediction_value_list"], findings["label_index_list"], findings["img_name_list"]))
sorted_list.sort(key=lambda x: x[0], reverse=True)

pred_sorted = [row[0] for row in sorted_list]
lab_sorted = [row[1] for row in sorted_list]
name_sorted = [row[2] for row in sorted_list]

pseudo_sorted = {
    "prediction_value_list": pred_sorted,
    "label_index_list": lab_sorted,
    "img_name_list": name_sorted
}

# %% [markdown]
# ### Create new dataset by combining train data and new findings

# %%
unlab_data_root = pathlib.Path('/content/unlabeled-images/images')

# %%
def create_new_dataset(dataset, pseudo_sorted, datasets_bin):

  new_findings, added_samples = resample_new_dataset(pseudo_sorted, datasets_bin[-1])

  # create a Dataset whose elements are slices of the new findings
  findings_tensor = tf.data.Dataset.from_tensor_slices(new_findings)
  dataset["mix_train"] = dataset["mix_train"].concatenate(findings_tensor) # Combine the train dataset with new findings

  # count class samples of the combined dataset
  datasets_bin.append(count_class_samples(dataset["mix_train"], NUMBER_CLASSES))

  return datasets_bin, added_samples

def read_unlab_images(tensor, folder):
    # function to read unlabelled images
    
    tensor = tensor.numpy().decode("utf-8")
    image = tf.io.read_file("{}/{}".format(folder, tensor))
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [128, 128])
    return image

# This is done because images should be added to classes equally without adding hundreds of images to
# one class, and nothing for another
def resample_new_dataset(pseudo, initial_class_distrib):

    # Add the new findings to respective classes
    added = {}
    newly_added_total = 0
        
    print ('Resample')
    print ("-"*50)

    latest_additions = ([], [])
    latest_additions_filepaths = []

    # Convert the input to an array.
    label_array = np.asarray(pseudo["label_index_list"], dtype=np.uint8) 

    for class_index in range(NUMBER_CLASSES):

        # check the number of samples currently in the class
        sample_count = initial_class_distrib[class_index]

        indexes = np.where(label_array == class_index)[0]
        num_latest_additions = len(indexes)

        count = 0
        for count, i in enumerate(indexes, start=1):
            if sample_count >= 1000:
                count -= 1 # one count should be reduced as it is already added using enumerate()
                break
            tensor = pseudo["img_name_list"][i]
            image = read_unlab_images(tensor, unlab_data_root)
            
            # append the images
            latest_additions[0].append(image)  
            # append the labels of the images                        
            latest_additions[1].append(pseudo["label_index_list"][i])     
            # append the filepaths of the images     
            latest_additions_filepaths.append(pseudo["img_name_list"][i])
            sample_count += 1
            
        newly_added_total += count

        print ("{:30}: newly added {} samples out of {} samples".format(CLASS_NAMES[class_index], count, num_latest_additions))
            
        added[CLASS_NAMES[class_index]] = [count, num_latest_additions]
    
    print ("-"*50)
    print ("Total number of {} samples was added to the training dataset".format(newly_added_total))
        
    return latest_additions, latest_additions_filepaths

# %%
datasets_bin, added_samples = create_new_dataset(dataset, pseudo_sorted, datasets_bin)

original_unlab_size = DATASET_SIZE_UNLAB
new_unlab_size = DATASET_SIZE_UNLAB - len(added_samples)
original_train_size = int(np.sum(datasets_bin[-2]))
new_train_size = int(np.sum(datasets_bin[-1]))

print("\nFinal Dataset Details:")
print("Newly added Samples: ", len(added_samples))
print("Unlabelled dataset size changed from {} to {} samples".format(original_unlab_size, new_unlab_size))
print("Labelled dataset size changed from {} to {} samples".format(original_train_size, new_train_size))

# Update dataset sizes
DATASET_SIZE_UNLAB -= len(added_samples)
DATASET_SIZE_TRAIN = new_train_size
STEPS_TRAIN = new_train_size//BATCH_SIZE
# Out:
# Resample
# --------------------------------------------------
# retroflex-stomach          : added 0/862 samples
# esophagitis-b-d            : added 81/81 samples
# ulcerative-colitis-grade-1-2: added 0/0 samples
# z-line                     : added 37/37 samples
# barretts-short-segment     : added 106/106 samples
# ileum                      : added 65/65 samples
# retroflex-rectum           : added 91/91 samples
# barretts                   : added 46/46 samples
# ulcerative-colitis-grade-2-3: added 18/18 samples
# ulcerative-colitis-grade-0-1: added 181/181 samples
# bbps-0-1                   : added 13/13 samples
# ulcerative-colitis-grade-2 : added 0/706 samples
# polyps                     : added 0/2510 samples
# dyed-resection-margins     : added 136/136 samples
# impacted-stool             : added 0/0 samples
# ulcerative-colitis-grade-1 : added 38/38 samples
# cecum                      : added 0/1056 samples
# ulcerative-colitis-grade-3 : added 80/80 samples
# hemorrhoids                : added 1/1 samples
# bbps-2-3                   : added 71/71 samples
# esophagitis-a              : added 72/72 samples
# dyed-lifted-polyps         : added 136/136 samples
# pylorus                    : added 0/2791 samples
# --------------------------------------------------
# Added a total of 1172 samples to the training dataset. New dataset size is 11830.
#
# Final Dataset Details:
# Newly added Samples:  1172
# Unlabelled dataset size changed from 96213 to 95041 samples
# Labelled dataset size changed from 10658 to 11830 samples

# %% [markdown]
# ##Use the new dataset to train a pseudo model

# %%
# Pseudo directory
record_dir = "./records/{}".format("pseudo_model")
pathlib.Path(record_dir).mkdir(parents=True, exist_ok=True) # record_directory

dataset["train"] = resample(dataset["mix_train"], NUMBER_CLASSES)
dataset["train"] = (
  dataset["train"]
  .shuffle(buffer_size=3000, seed=tf.constant(1500, tf.int64))
  .repeat()
  .map(dataset_augmentation(), num_parallel_calls=AUTOTUNE)
  .batch(BATCH_SIZE, drop_remainder=False)
  .prefetch(buffer_size=AUTOTUNE)
)

# %%
new_model = model_define()
# Out:
# (None, None, None, 1536)
# (None, None, None, 2048)
# 3584
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2_0_1 (InputLayer)       [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_203_0 (Conv2D)          (None, None, None,   864         ['input_2_0_1[0][0]']
#                                 32)
#
#  batch_normalization_203_0 (Bat  (None, None, None,   96         ['conv2d_203_0[0][0]']
#  chNormalization)               32)
#
#  activation_203_0 (Activation)  (None, None, None,   0           ['batch_normalization_203_0[0][0]
#                                 32)                              ']
#
#  conv2d_204_0 (Conv2D)          (None, None, None,   9216        ['activation_203_0[0][0]']
#                                 32)
#
#  batch_normalization_204_0 (Bat  (None, None, None,   96         ['conv2d_204_0[0][0]']
#  chNormalization)               32)
#
#  activation_204_0 (Activation)  (None, None, None,   0           ['batch_normalization_204_0[0][0]
#                                 32)                              ']
#
#  conv2d_205_0 (Conv2D)          (None, None, None,   18432       ['activation_204_0[0][0]']
#                                 64)
#
#  batch_normalization_205_0 (Bat  (None, None, None,   192        ['conv2d_205_0[0][0]']
#  chNormalization)               64)
#
#  activation_205_0 (Activation)  (None, None, None,   0           ['batch_normalization_205_0[0][0]
#                                 64)                              ']
#
#  max_pooling2d_4_0 (MaxPooling2  (None, None, None,   0          ['activation_205_0[0][0]']
#  D)                             64)
#
#  conv2d_206_0 (Conv2D)          (None, None, None,   5120        ['max_pooling2d_4_0[0][0]']
#                                 80)
#
#  batch_normalization_206_0 (Bat  (None, None, None,   240        ['conv2d_206_0[0][0]']
#  chNormalization)               80)
#
#  activation_206_0 (Activation)  (None, None, None,   0           ['batch_normalization_206_0[0][0]
#                                 80)                              ']
#
#  conv2d_207_0 (Conv2D)          (None, None, None,   138240      ['activation_206_0[0][0]']
#                                 192)
#
#  batch_normalization_207_0 (Bat  (None, None, None,   576        ['conv2d_207_0[0][0]']
#  chNormalization)               192)
#
#  activation_207_0 (Activation)  (None, None, None,   0           ['batch_normalization_207_0[0][0]
#                                 192)                             ']
#
#  max_pooling2d_5_0 (MaxPooling2  (None, None, None,   0          ['activation_207_0[0][0]']
#  D)                             192)
#
#  conv2d_211_0 (Conv2D)          (None, None, None,   12288       ['max_pooling2d_5_0[0][0]']
#                                 64)
#
#  batch_normalization_211_0 (Bat  (None, None, None,   192        ['conv2d_211_0[0][0]']
#  chNormalization)               64)
#
#  activation_211_0 (Activation)  (None, None, None,   0           ['batch_normalization_211_0[0][0]
#                                 64)                              ']
#
#  conv2d_209_0 (Conv2D)          (None, None, None,   9216        ['max_pooling2d_5_0[0][0]']
#                                 48)
#
#  conv2d_212_0 (Conv2D)          (None, None, None,   55296       ['activation_211_0[0][0]']
#                                 96)
#
#  batch_normalization_209_0 (Bat  (None, None, None,   144        ['conv2d_209_0[0][0]']
#  chNormalization)               48)
#
#  batch_normalization_212_0 (Bat  (None, None, None,   288        ['conv2d_212_0[0][0]']
#  chNormalization)               96)
#
#  activation_209_0 (Activation)  (None, None, None,   0           ['batch_normalization_209_0[0][0]
#                                 48)                              ']
#
#  activation_212_0 (Activation)  (None, None, None,   0           ['batch_normalization_212_0[0][0]
#                                 96)                              ']
#
#  average_pooling2d_1_0 (Average  (None, None, None,   0          ['max_pooling2d_5_0[0][0]']
#  Pooling2D)                     192)
#
#  conv2d_208_0 (Conv2D)          (None, None, None,   18432       ['max_pooling2d_5_0[0][0]']
#                                 96)
#
#  conv2d_210_0 (Conv2D)          (None, None, None,   76800       ['activation_209_0[0][0]']
#                                 64)
#
#  conv2d_213_0 (Conv2D)          (None, None, None,   82944       ['activation_212_0[0][0]']
#                                 96)
#
#  conv2d_214_0 (Conv2D)          (None, None, None,   12288       ['average_pooling2d_1_0[0][0]']
#                                 64)
#
#  batch_normalization_208_0 (Bat  (None, None, None,   288        ['conv2d_208_0[0][0]']
#  chNormalization)               96)
#
#  batch_normalization_210_0 (Bat  (None, None, None,   192        ['conv2d_210_0[0][0]']
#  chNormalization)               64)
#
#  batch_normalization_213_0 (Bat  (None, None, None,   288        ['conv2d_213_0[0][0]']
#  chNormalization)               96)
#
#  batch_normalization_214_0 (Bat  (None, None, None,   192        ['conv2d_214_0[0][0]']
#  chNormalization)               64)
#
#  activation_208_0 (Activation)  (None, None, None,   0           ['batch_normalization_208_0[0][0]
#                                 96)                              ']
#
#  activation_210_0 (Activation)  (None, None, None,   0           ['batch_normalization_210_0[0][0]
#                                 64)                              ']
#
#  activation_213_0 (Activation)  (None, None, None,   0           ['batch_normalization_213_0[0][0]
#                                 96)                              ']
#
#  activation_214_0 (Activation)  (None, None, None,   0           ['batch_normalization_214_0[0][0]
#                                 64)                              ']
#
#  mixed_5b_0 (Concatenate)       (None, None, None,   0           ['activation_208_0[0][0]',
#                                 320)                              'activation_210_0[0][0]',
#                                                                   'activation_213_0[0][0]',
#                                                                   'activation_214_0[0][0]']
#
#  conv2d_218_0 (Conv2D)          (None, None, None,   10240       ['mixed_5b_0[0][0]']
#                                 32)
#
#  batch_normalization_218_0 (Bat  (None, None, None,   96         ['conv2d_218_0[0][0]']
#  chNormalization)               32)
#
#  activation_218_0 (Activation)  (None, None, None,   0           ['batch_normalization_218_0[0][0]
#                                 32)                              ']
#
#  conv2d_216_0 (Conv2D)          (None, None, None,   10240       ['mixed_5b_0[0][0]']
#                                 32)
#
#  conv2d_219_0 (Conv2D)          (None, None, None,   13824       ['activation_218_0[0][0]']
#                                 48)
#
#  batch_normalization_216_0 (Bat  (None, None, None,   96         ['conv2d_216_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_219_0 (Bat  (None, None, None,   144        ['conv2d_219_0[0][0]']
#  chNormalization)               48)
#
#  activation_216_0 (Activation)  (None, None, None,   0           ['batch_normalization_216_0[0][0]
#                                 32)                              ']
#
#  activation_219_0 (Activation)  (None, None, None,   0           ['batch_normalization_219_0[0][0]
#                                 48)                              ']
#
#  conv2d_215_0 (Conv2D)          (None, None, None,   10240       ['mixed_5b_0[0][0]']
#                                 32)
#
#  conv2d_217_0 (Conv2D)          (None, None, None,   9216        ['activation_216_0[0][0]']
#                                 32)
#
#  conv2d_220_0 (Conv2D)          (None, None, None,   27648       ['activation_219_0[0][0]']
#                                 64)
#
#  batch_normalization_215_0 (Bat  (None, None, None,   96         ['conv2d_215_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_217_0 (Bat  (None, None, None,   96         ['conv2d_217_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_220_0 (Bat  (None, None, None,   192        ['conv2d_220_0[0][0]']
#  chNormalization)               64)
#
#  activation_215_0 (Activation)  (None, None, None,   0           ['batch_normalization_215_0[0][0]
#                                 32)                              ']
#
#  activation_217_0 (Activation)  (None, None, None,   0           ['batch_normalization_217_0[0][0]
#                                 32)                              ']
#
#  activation_220_0 (Activation)  (None, None, None,   0           ['batch_normalization_220_0[0][0]
#                                 64)                              ']
#
#  block35_1_mixed_0 (Concatenate  (None, None, None,   0          ['activation_215_0[0][0]',
#  )                              128)                              'activation_217_0[0][0]',
#                                                                   'activation_220_0[0][0]']
#
#  block35_1_conv_0 (Conv2D)      (None, None, None,   41280       ['block35_1_mixed_0[0][0]']
#                                 320)
#
#  block35_1_0 (Lambda)           (None, None, None,   0           ['mixed_5b_0[0][0]',
#                                 320)                              'block35_1_conv_0[0][0]']
#
#  block35_1_ac_0 (Activation)    (None, None, None,   0           ['block35_1_0[0][0]']
#                                 320)
#
#  conv2d_224_0 (Conv2D)          (None, None, None,   10240       ['block35_1_ac_0[0][0]']
#                                 32)
#
#  batch_normalization_224_0 (Bat  (None, None, None,   96         ['conv2d_224_0[0][0]']
#  chNormalization)               32)
#
#  activation_224_0 (Activation)  (None, None, None,   0           ['batch_normalization_224_0[0][0]
#                                 32)                              ']
#
#  conv2d_222_0 (Conv2D)          (None, None, None,   10240       ['block35_1_ac_0[0][0]']
#                                 32)
#
#  conv2d_225_0 (Conv2D)          (None, None, None,   13824       ['activation_224_0[0][0]']
#                                 48)
#
#  batch_normalization_222_0 (Bat  (None, None, None,   96         ['conv2d_222_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_225_0 (Bat  (None, None, None,   144        ['conv2d_225_0[0][0]']
#  chNormalization)               48)
#
#  activation_222_0 (Activation)  (None, None, None,   0           ['batch_normalization_222_0[0][0]
#                                 32)                              ']
#
#  activation_225_0 (Activation)  (None, None, None,   0           ['batch_normalization_225_0[0][0]
#                                 48)                              ']
#
#  conv2d_221_0 (Conv2D)          (None, None, None,   10240       ['block35_1_ac_0[0][0]']
#                                 32)
#
#  conv2d_223_0 (Conv2D)          (None, None, None,   9216        ['activation_222_0[0][0]']
#                                 32)
#
#  conv2d_226_0 (Conv2D)          (None, None, None,   27648       ['activation_225_0[0][0]']
#                                 64)
#
#  batch_normalization_221_0 (Bat  (None, None, None,   96         ['conv2d_221_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_223_0 (Bat  (None, None, None,   96         ['conv2d_223_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_226_0 (Bat  (None, None, None,   192        ['conv2d_226_0[0][0]']
#  chNormalization)               64)
#
#  activation_221_0 (Activation)  (None, None, None,   0           ['batch_normalization_221_0[0][0]
#                                 32)                              ']
#
#  activation_223_0 (Activation)  (None, None, None,   0           ['batch_normalization_223_0[0][0]
#                                 32)                              ']
#
#  activation_226_0 (Activation)  (None, None, None,   0           ['batch_normalization_226_0[0][0]
#                                 64)                              ']
#
#  block35_2_mixed_0 (Concatenate  (None, None, None,   0          ['activation_221_0[0][0]',
#  )                              128)                              'activation_223_0[0][0]',
#                                                                   'activation_226_0[0][0]']
#
#  block35_2_conv_0 (Conv2D)      (None, None, None,   41280       ['block35_2_mixed_0[0][0]']
#                                 320)
#
#  block35_2_0 (Lambda)           (None, None, None,   0           ['block35_1_ac_0[0][0]',
#                                 320)                              'block35_2_conv_0[0][0]']
#
#  block35_2_ac_0 (Activation)    (None, None, None,   0           ['block35_2_0[0][0]']
#                                 320)
#
#  conv2d_230_0 (Conv2D)          (None, None, None,   10240       ['block35_2_ac_0[0][0]']
#                                 32)
#
#  batch_normalization_230_0 (Bat  (None, None, None,   96         ['conv2d_230_0[0][0]']
#  chNormalization)               32)
#
#  activation_230_0 (Activation)  (None, None, None,   0           ['batch_normalization_230_0[0][0]
#                                 32)                              ']
#
#  conv2d_228_0 (Conv2D)          (None, None, None,   10240       ['block35_2_ac_0[0][0]']
#                                 32)
#
#  conv2d_231_0 (Conv2D)          (None, None, None,   13824       ['activation_230_0[0][0]']
#                                 48)
#
#  batch_normalization_228_0 (Bat  (None, None, None,   96         ['conv2d_228_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_231_0 (Bat  (None, None, None,   144        ['conv2d_231_0[0][0]']
#  chNormalization)               48)
#
#  activation_228_0 (Activation)  (None, None, None,   0           ['batch_normalization_228_0[0][0]
#                                 32)                              ']
#
#  activation_231_0 (Activation)  (None, None, None,   0           ['batch_normalization_231_0[0][0]
#                                 48)                              ']
#
#  conv2d_227_0 (Conv2D)          (None, None, None,   10240       ['block35_2_ac_0[0][0]']
#                                 32)
#
#  conv2d_229_0 (Conv2D)          (None, None, None,   9216        ['activation_228_0[0][0]']
#                                 32)
#
#  conv2d_232_0 (Conv2D)          (None, None, None,   27648       ['activation_231_0[0][0]']
#                                 64)
#
#  batch_normalization_227_0 (Bat  (None, None, None,   96         ['conv2d_227_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_229_0 (Bat  (None, None, None,   96         ['conv2d_229_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_232_0 (Bat  (None, None, None,   192        ['conv2d_232_0[0][0]']
#  chNormalization)               64)
#
#  activation_227_0 (Activation)  (None, None, None,   0           ['batch_normalization_227_0[0][0]
#                                 32)                              ']
#
#  activation_229_0 (Activation)  (None, None, None,   0           ['batch_normalization_229_0[0][0]
#                                 32)                              ']
#
#  activation_232_0 (Activation)  (None, None, None,   0           ['batch_normalization_232_0[0][0]
#                                 64)                              ']
#
#  block35_3_mixed_0 (Concatenate  (None, None, None,   0          ['activation_227_0[0][0]',
#  )                              128)                              'activation_229_0[0][0]',
#                                                                   'activation_232_0[0][0]']
#
#  block35_3_conv_0 (Conv2D)      (None, None, None,   41280       ['block35_3_mixed_0[0][0]']
#                                 320)
#
#  block35_3_0 (Lambda)           (None, None, None,   0           ['block35_2_ac_0[0][0]',
#                                 320)                              'block35_3_conv_0[0][0]']
#
#  block35_3_ac_0 (Activation)    (None, None, None,   0           ['block35_3_0[0][0]']
#                                 320)
#
#  conv2d_236_0 (Conv2D)          (None, None, None,   10240       ['block35_3_ac_0[0][0]']
#                                 32)
#
#  batch_normalization_236_0 (Bat  (None, None, None,   96         ['conv2d_236_0[0][0]']
#  chNormalization)               32)
#
#  activation_236_0 (Activation)  (None, None, None,   0           ['batch_normalization_236_0[0][0]
#                                 32)                              ']
#
#  conv2d_234_0 (Conv2D)          (None, None, None,   10240       ['block35_3_ac_0[0][0]']
#                                 32)
#
#  conv2d_237_0 (Conv2D)          (None, None, None,   13824       ['activation_236_0[0][0]']
#                                 48)
#
#  batch_normalization_234_0 (Bat  (None, None, None,   96         ['conv2d_234_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_237_0 (Bat  (None, None, None,   144        ['conv2d_237_0[0][0]']
#  chNormalization)               48)
#
#  activation_234_0 (Activation)  (None, None, None,   0           ['batch_normalization_234_0[0][0]
#                                 32)                              ']
#
#  activation_237_0 (Activation)  (None, None, None,   0           ['batch_normalization_237_0[0][0]
#                                 48)                              ']
#
#  conv2d_233_0 (Conv2D)          (None, None, None,   10240       ['block35_3_ac_0[0][0]']
#                                 32)
#
#  conv2d_235_0 (Conv2D)          (None, None, None,   9216        ['activation_234_0[0][0]']
#                                 32)
#
#  conv2d_238_0 (Conv2D)          (None, None, None,   27648       ['activation_237_0[0][0]']
#                                 64)
#
#  batch_normalization_233_0 (Bat  (None, None, None,   96         ['conv2d_233_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_235_0 (Bat  (None, None, None,   96         ['conv2d_235_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_238_0 (Bat  (None, None, None,   192        ['conv2d_238_0[0][0]']
#  chNormalization)               64)
#
#  activation_233_0 (Activation)  (None, None, None,   0           ['batch_normalization_233_0[0][0]
#                                 32)                              ']
#
#  activation_235_0 (Activation)  (None, None, None,   0           ['batch_normalization_235_0[0][0]
#                                 32)                              ']
#
#  activation_238_0 (Activation)  (None, None, None,   0           ['batch_normalization_238_0[0][0]
#                                 64)                              ']
#
#  block35_4_mixed_0 (Concatenate  (None, None, None,   0          ['activation_233_0[0][0]',
#  )                              128)                              'activation_235_0[0][0]',
#                                                                   'activation_238_0[0][0]']
#
#  block35_4_conv_0 (Conv2D)      (None, None, None,   41280       ['block35_4_mixed_0[0][0]']
#                                 320)
#
#  block35_4_0 (Lambda)           (None, None, None,   0           ['block35_3_ac_0[0][0]',
#                                 320)                              'block35_4_conv_0[0][0]']
#
#  block35_4_ac_0 (Activation)    (None, None, None,   0           ['block35_4_0[0][0]']
#                                 320)
#
#  conv2d_242_0 (Conv2D)          (None, None, None,   10240       ['block35_4_ac_0[0][0]']
#                                 32)
#
#  batch_normalization_242_0 (Bat  (None, None, None,   96         ['conv2d_242_0[0][0]']
#  chNormalization)               32)
#
#  activation_242_0 (Activation)  (None, None, None,   0           ['batch_normalization_242_0[0][0]
#                                 32)                              ']
#
#  conv2d_240_0 (Conv2D)          (None, None, None,   10240       ['block35_4_ac_0[0][0]']
#                                 32)
#
#  conv2d_243_0 (Conv2D)          (None, None, None,   13824       ['activation_242_0[0][0]']
#                                 48)
#
#  batch_normalization_240_0 (Bat  (None, None, None,   96         ['conv2d_240_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_243_0 (Bat  (None, None, None,   144        ['conv2d_243_0[0][0]']
#  chNormalization)               48)
#
#  activation_240_0 (Activation)  (None, None, None,   0           ['batch_normalization_240_0[0][0]
#                                 32)                              ']
#
#  activation_243_0 (Activation)  (None, None, None,   0           ['batch_normalization_243_0[0][0]
#                                 48)                              ']
#
#  conv2d_239_0 (Conv2D)          (None, None, None,   10240       ['block35_4_ac_0[0][0]']
#                                 32)
#
#  conv2d_241_0 (Conv2D)          (None, None, None,   9216        ['activation_240_0[0][0]']
#                                 32)
#
#  conv2d_244_0 (Conv2D)          (None, None, None,   27648       ['activation_243_0[0][0]']
#                                 64)
#
#  batch_normalization_239_0 (Bat  (None, None, None,   96         ['conv2d_239_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_241_0 (Bat  (None, None, None,   96         ['conv2d_241_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_244_0 (Bat  (None, None, None,   192        ['conv2d_244_0[0][0]']
#  chNormalization)               64)
#
#  activation_239_0 (Activation)  (None, None, None,   0           ['batch_normalization_239_0[0][0]
#                                 32)                              ']
#
#  activation_241_0 (Activation)  (None, None, None,   0           ['batch_normalization_241_0[0][0]
#                                 32)                              ']
#
#  activation_244_0 (Activation)  (None, None, None,   0           ['batch_normalization_244_0[0][0]
#                                 64)                              ']
#
#  block35_5_mixed_0 (Concatenate  (None, None, None,   0          ['activation_239_0[0][0]',
#  )                              128)                              'activation_241_0[0][0]',
#                                                                   'activation_244_0[0][0]']
#
#  block35_5_conv_0 (Conv2D)      (None, None, None,   41280       ['block35_5_mixed_0[0][0]']
#                                 320)
#
#  block35_5_0 (Lambda)           (None, None, None,   0           ['block35_4_ac_0[0][0]',
#                                 320)                              'block35_5_conv_0[0][0]']
#
#  block35_5_ac_0 (Activation)    (None, None, None,   0           ['block35_5_0[0][0]']
#                                 320)
#
#  conv2d_248_0 (Conv2D)          (None, None, None,   10240       ['block35_5_ac_0[0][0]']
#                                 32)
#
#  batch_normalization_248_0 (Bat  (None, None, None,   96         ['conv2d_248_0[0][0]']
#  chNormalization)               32)
#
#  activation_248_0 (Activation)  (None, None, None,   0           ['batch_normalization_248_0[0][0]
#                                 32)                              ']
#
#  conv2d_246_0 (Conv2D)          (None, None, None,   10240       ['block35_5_ac_0[0][0]']
#                                 32)
#
#  conv2d_249_0 (Conv2D)          (None, None, None,   13824       ['activation_248_0[0][0]']
#                                 48)
#
#  batch_normalization_246_0 (Bat  (None, None, None,   96         ['conv2d_246_0[0][0]']
#  chNormalization)               32)
#
#  batch_normalization_249_0 (Bat  (None, None, None,   144        ['conv2d_249_0[0][0]']
#  chNormalization)               48)
#
# ...
#
#  activation_401_0 (Activation)  (None, None, None,   0           ['batch_normalization_401_0[0][0]
#                                 256)                             ']
#
#  conv5_block1_out_1 (Activation  (None, None, None,   0          ['conv5_block1_add_1[0][0]']
#  )                              2048)
#
#  block8_9_mixed_0 (Concatenate)  (None, None, None,   0          ['activation_398_0[0][0]',
#                                 448)                              'activation_401_0[0][0]']
#
#  conv5_block2_1_conv_1 (Conv2D)  (None, None, None,   1049088    ['conv5_block1_out_1[0][0]']
#                                 512)
#
#  block8_9_conv_0 (Conv2D)       (None, None, None,   933920      ['block8_9_mixed_0[0][0]']
#                                 2080)
#
#  conv5_block2_1_bn_1 (BatchNorm  (None, None, None,   2048       ['conv5_block2_1_conv_1[0][0]']
#  alization)                     512)
#
#  block8_9_0 (Lambda)            (None, None, None,   0           ['block8_8_ac_0[0][0]',
#                                 2080)                             'block8_9_conv_0[0][0]']
#
#  conv5_block2_1_relu_1 (Activat  (None, None, None,   0          ['conv5_block2_1_bn_1[0][0]']
#  ion)                           512)
#
#  block8_9_ac_0 (Activation)     (None, None, None,   0           ['block8_9_0[0][0]']
#                                 2080)
#
#  conv5_block2_2_conv_1 (Conv2D)  (None, None, None,   2359808    ['conv5_block2_1_relu_1[0][0]']
#                                 512)
#
#  conv2d_403_0 (Conv2D)          (None, None, None,   399360      ['block8_9_ac_0[0][0]']
#                                 192)
#
#  conv5_block2_2_bn_1 (BatchNorm  (None, None, None,   2048       ['conv5_block2_2_conv_1[0][0]']
#  alization)                     512)
#
#  batch_normalization_403_0 (Bat  (None, None, None,   576        ['conv2d_403_0[0][0]']
#  chNormalization)               192)
#
#  conv5_block2_2_relu_1 (Activat  (None, None, None,   0          ['conv5_block2_2_bn_1[0][0]']
#  ion)                           512)
#
#  activation_403_0 (Activation)  (None, None, None,   0           ['batch_normalization_403_0[0][0]
#                                 192)                             ']
#
#  conv5_block2_3_conv_1 (Conv2D)  (None, None, None,   1050624    ['conv5_block2_2_relu_1[0][0]']
#                                 2048)
#
#  conv2d_404_0 (Conv2D)          (None, None, None,   129024      ['activation_403_0[0][0]']
#                                 224)
#
#  conv5_block2_3_bn_1 (BatchNorm  (None, None, None,   8192       ['conv5_block2_3_conv_1[0][0]']
#  alization)                     2048)
#
#  batch_normalization_404_0 (Bat  (None, None, None,   672        ['conv2d_404_0[0][0]']
#  chNormalization)               224)
#
#  conv5_block2_add_1 (Add)       (None, None, None,   0           ['conv5_block1_out_1[0][0]',
#                                 2048)                             'conv5_block2_3_bn_1[0][0]']
#
#  activation_404_0 (Activation)  (None, None, None,   0           ['batch_normalization_404_0[0][0]
#                                 224)                             ']
#
#  conv5_block2_out_1 (Activation  (None, None, None,   0          ['conv5_block2_add_1[0][0]']
#  )                              2048)
#
#  conv2d_402_0 (Conv2D)          (None, None, None,   399360      ['block8_9_ac_0[0][0]']
#                                 192)
#
#  conv2d_405_0 (Conv2D)          (None, None, None,   172032      ['activation_404_0[0][0]']
#                                 256)
#
#  conv5_block3_1_conv_1 (Conv2D)  (None, None, None,   1049088    ['conv5_block2_out_1[0][0]']
#                                 512)
#
#  batch_normalization_402_0 (Bat  (None, None, None,   576        ['conv2d_402_0[0][0]']
#  chNormalization)               192)
#
#  batch_normalization_405_0 (Bat  (None, None, None,   768        ['conv2d_405_0[0][0]']
#  chNormalization)               256)
#
#  conv5_block3_1_bn_1 (BatchNorm  (None, None, None,   2048       ['conv5_block3_1_conv_1[0][0]']
#  alization)                     512)
#
#  activation_402_0 (Activation)  (None, None, None,   0           ['batch_normalization_402_0[0][0]
#                                 192)                             ']
#
#  activation_405_0 (Activation)  (None, None, None,   0           ['batch_normalization_405_0[0][0]
#                                 256)                             ']
#
#  conv5_block3_1_relu_1 (Activat  (None, None, None,   0          ['conv5_block3_1_bn_1[0][0]']
#  ion)                           512)
#
#  block8_10_mixed_0 (Concatenate  (None, None, None,   0          ['activation_402_0[0][0]',
#  )                              448)                              'activation_405_0[0][0]']
#
#  conv5_block3_2_conv_1 (Conv2D)  (None, None, None,   2359808    ['conv5_block3_1_relu_1[0][0]']
#                                 512)
#
#  block8_10_conv_0 (Conv2D)      (None, None, None,   933920      ['block8_10_mixed_0[0][0]']
#                                 2080)
#
#  conv5_block3_2_bn_1 (BatchNorm  (None, None, None,   2048       ['conv5_block3_2_conv_1[0][0]']
#  alization)                     512)
#
#  block8_10_0 (Lambda)           (None, None, None,   0           ['block8_9_ac_0[0][0]',
#                                 2080)                             'block8_10_conv_0[0][0]']
#
#  conv5_block3_2_relu_1 (Activat  (None, None, None,   0          ['conv5_block3_2_bn_1[0][0]']
#  ion)                           512)
#
#  conv_7b_0 (Conv2D)             (None, None, None,   3194880     ['block8_10_0[0][0]']
#                                 1536)
#
#  conv5_block3_3_conv_1 (Conv2D)  (None, None, None,   1050624    ['conv5_block3_2_relu_1[0][0]']
#                                 2048)
#
#  conv_7b_bn_0 (BatchNormalizati  (None, None, None,   4608       ['conv_7b_0[0][0]']
#  on)                            1536)
#
#  conv5_block3_3_bn_1 (BatchNorm  (None, None, None,   8192       ['conv5_block3_3_conv_1[0][0]']
#  alization)                     2048)
#
#  conv_7b_ac_0 (Activation)      (None, None, None,   0           ['conv_7b_bn_0[0][0]']
#                                 1536)
#
#  conv5_block3_add_1 (Add)       (None, None, None,   0           ['conv5_block2_out_1[0][0]',
#                                 2048)                             'conv5_block3_3_bn_1[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, None, None,   0          ['conv_7b_ac_0[0][0]']
#  D)                             1536)
#
#  conv5_block3_out_1 (Activation  (None, None, None,   0          ['conv5_block3_add_1[0][0]']
#  )                              2048)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['zero_padding2d_1[0][0]',
#                                 3584)                             'conv5_block3_out_1[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 3584)        0           ['concatenate_1[0][0]']
#  obalAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 3584)         0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 28)           100380      ['dropout_1[0][0]']
#
#  dense_4 (Dense)                (None, 3584)         103936      ['dense_3[0][0]']
#
#  multiply_1 (Multiply)          (None, None, None,   0           ['concatenate_1[0][0]',
#                                 3584)                             'dense_4[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 3584)        0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_5 (Dense)                (None, 23)           82455       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 78,211,219
# Trainable params: 78,097,555
# Non-trainable params: 113,664
# __________________________________________________________________________________________________

# %%
start_time = time.time()

model_train = model.fit(
    dataset["train"],
    steps_per_epoch = STEPS_TRAIN, 
    epochs = 15,
    validation_data = dataset["val"],
    validation_steps = STEPS_VAL,
    validation_freq = 1,
    verbose = 1
)
print ("Time spent on training: {:.2f} minutes.".format(np.round(time.time() - start_time)/60))
# Out:
# Epoch 1/15
# 1332/1332 [==============================] - 231s 166ms/step - loss: 0.3713 - sparse_categorical_accuracy: 0.8675 - val_loss: 0.7447 - val_sparse_categorical_accuracy: 0.7873
# Epoch 2/15
# 1332/1332 [==============================] - 221s 166ms/step - loss: 0.3588 - sparse_categorical_accuracy: 0.8743 - val_loss: 0.8862 - val_sparse_categorical_accuracy: 0.7973
# Epoch 3/15
# 1332/1332 [==============================] - 220s 165ms/step - loss: 0.3392 - sparse_categorical_accuracy: 0.8784 - val_loss: 0.7195 - val_sparse_categorical_accuracy: 0.8066
# Epoch 4/15
# 1332/1332 [==============================] - 219s 164ms/step - loss: 0.3192 - sparse_categorical_accuracy: 0.8825 - val_loss: 0.7895 - val_sparse_categorical_accuracy: 0.7954
# Epoch 5/15
# 1332/1332 [==============================] - 219s 165ms/step - loss: 0.2889 - sparse_categorical_accuracy: 0.8949 - val_loss: 0.7246 - val_sparse_categorical_accuracy: 0.8103
# Epoch 6/15
# 1332/1332 [==============================] - 219s 164ms/step - loss: 0.2917 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.6449 - val_sparse_categorical_accuracy: 0.8364
# Epoch 7/15
# 1332/1332 [==============================] - 219s 165ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.7708 - val_sparse_categorical_accuracy: 0.8197
# Epoch 8/15
# 1332/1332 [==============================] - 218s 164ms/step - loss: 0.2668 - sparse_categorical_accuracy: 0.9024 - val_loss: 0.8043 - val_sparse_categorical_accuracy: 0.7966
# Epoch 9/15
# 1332/1332 [==============================] - 220s 165ms/step - loss: 0.2423 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.9871 - val_sparse_categorical_accuracy: 0.7705
# Epoch 10/15
# 1332/1332 [==============================] - 219s 165ms/step - loss: 0.2603 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.8141
# Epoch 11/15
# 1332/1332 [==============================] - 222s 167ms/step - loss: 0.2386 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.7227 - val_sparse_categorical_accuracy: 0.8364
# Epoch 12/15
# 1332/1332 [==============================] - 219s 164ms/step - loss: 0.2353 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.7341 - val_sparse_categorical_accuracy: 0.8215
# Epoch 13/15
# 1332/1332 [==============================] - 220s 165ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.6315 - val_sparse_categorical_accuracy: 0.8545
# Epoch 14/15
# 1332/1332 [==============================] - 220s 165ms/step - loss: 0.2154 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.8003 - val_sparse_categorical_accuracy: 0.8277
# Epoch 15/15
# 1332/1332 [==============================] - 221s 166ms/step - loss: 0.1912 - sparse_categorical_accuracy: 0.9334 - val_loss: 0.7679 - val_sparse_categorical_accuracy: 0.8458
# Time spent on training: 55.37 minutes.

# %% [markdown]
# ### Model Evaluation

# %%
cd /content/drive/MyDrive/Colab Notebooks (1)/Experiments/InceptionResNetV2+ResNet50/Exp1
# Out:
# /content/drive/MyDrive/Colab Notebooks (1)/Experiments/InceptionResNetV2+ResNet50/Exp1

# %%
model.save('hyperkvasir_InceptionResNetV2+ResNet50_student.h5')

# %%
cd /content
# Out:
# /content

# %%
true_categories, predicted_categories = calculate_true_and_predicted_cat(model, dataset)
using_evaluation_metrics(model_train, true_categories, predicted_categories)

# Plot the Confusion Matrix
cm = metrics.confusion_matrix(true_categories, predicted_categories)
plot_confusion_matrix(cm, CLASS_NAMES)
# Out:
# 199/199 [==============================] - 11s 50ms/step - loss: 0.6975 - sparse_categorical_accuracy: 0.8398
#
# Test Accuracy:  [0.6974593997001648, 0.8398241400718689]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   # Remove the CWD from sys.path while we load stuff.
# Accuracy score is : 0.8391739674593242
# Precision score is : 0.8443350526175584
# Recall score is : 0.8391739674593242
# F1 Score is : 0.8367300083795888
# Cohen Kappa Score : 0.8254863241968676
# MCC : 0.8260921453545367
#
# Classification Report:
#                               precision    recall  f1-score   support
#
#            retroflex-stomach      0.884     0.991     0.934       115
#              esophagitis-b-d      0.564     0.564     0.564        39
# ulcerative-colitis-grade-1-2      0.000     0.000     0.000         2
#                       z-line      0.744     0.850     0.793       140
#       barretts-short-segment      0.125     0.125     0.125         8
#                        ileum      0.000     0.000     0.000         1
#             retroflex-rectum      0.979     0.797     0.879        59
#                     barretts      1.000     0.167     0.286         6
# ulcerative-colitis-grade-2-3      0.000     0.000     0.000         4
# ulcerative-colitis-grade-0-1      0.167     0.200     0.182         5
#                     bbps-0-1      0.969     0.969     0.969        97
#   ulcerative-colitis-grade-2      0.459     0.682     0.549        66
#                       polyps      0.984     0.818     0.894       154
#       dyed-resection-margins      0.905     0.899     0.902       148
#               impacted-stool      0.769     1.000     0.870        20
#   ulcerative-colitis-grade-1      0.333     0.200     0.250        30
#                        cecum      1.000     0.934     0.966       151
#   ulcerative-colitis-grade-3      0.556     0.500     0.526        20
#                  hemorrhoids      0.000     0.000     0.000         1
#                     bbps-2-3      0.988     0.965     0.976       172
#                esophagitis-a      0.351     0.217     0.268        60
#           dyed-lifted-polyps      0.870     0.893     0.882       150
#                      pylorus      0.914     0.987     0.949       150
#
#                     accuracy                          0.839      1598
#                    macro avg      0.590     0.555     0.555      1598
#                 weighted avg      0.844     0.839     0.837      1598
#
# Confusion Matrix
# Normalized confusion matrix
